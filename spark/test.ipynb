# %%
from spark_session import create_spark_session

spark = create_spark_session()

df = spark.read.parquet("hdfs://localhost:9000/jobs/processed/jobs_cleaned")

df.select("skills_raw").show(20, truncate=False)
# Out:
# +----------+
# |skills_raw|
# +----------+
# |NULL      |
# |[]        |
# |[]        |
# |[]        |
# |[]        |
# |[]        |
# |[]        |
# |[]        |
# |[]        |
# |[]        |
# |[]        |
# |[]        |
# |[]        |
# |[]        |
# |[]        |
# |[]        |
# |[]        |
# |[]        |
# |[]        |
# |[]        |
# +----------+
# only showing top 20 rows

# %%
# Out:
# The kernel failed to start due to the missing module 'pygments'. Consider installing this module.
#
# Click <a href='https://aka.ms/kernelFailuresMissingModule'>here</a> for more info.
